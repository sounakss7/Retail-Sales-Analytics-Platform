# %% [markdown]
# # Data Cleaning Notebook
#
# This notebook documents the cleaning workflow for the Superstore dataset.

# %%
import pandas as pd
from pathlib import Path
import sys
sys.path.append('../src')
from retail_analytics.cleaning import load_and_clean_superstore

raw_path = Path('../data/raw/superstore.csv')
df, report = load_and_clean_superstore(str(raw_path), return_report=True)
print(report)
df.head()
